# %%
import sys,os
sys.path.append(os.path.abspath("../"))
# %pylab notebook
from experiments import pico as pico
from experiments import litebird as litebird
import pysm
import healpy as h

def ensure_dir(file_path):
    directory = os.path.dirname(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)
        
respath="../results/"
ensure_dir(respath)

share_datapath="/scratch/nas_chluba/specdist/arotti/share_data/"
# share_datapath="../dataout/"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
figure()
plot(pico.channels,pico.noiserms,label="PICO")
plot(litebird.channels,litebird.noiserms,label="LiteBird")
semilogy()
legend(loc=0,fontsize=12)
xlabel("Channels",fontsize=12)
ylabel("Noise rms $\mu$K-arcmin",fontsize=12)
grid(which="both",alpha=0.5,linestyle="dashed")
savefig(respath + "compare_noise_litebird_pico.pdf",bbox_inches="tight")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Common settings

# %%
nside=512
pix_idx=arange(h.nside2npix(nside))
sky_config = {
    'synchrotron' : pysm.nominal.models("s2", nside,pixel_indices=pix_idx),
    'dust' : pysm.nominal.models("d2", nside,pixel_indices=pix_idx),
    #'freefree' : pysm.nominal.models("f1", nside,pixel_indices=pix_idx),
    'cmb' : pysm.nominal.models("c1", nside,pixel_indices=pix_idx),
    #'ame' : models("a1", nside,pixel_indices=pix_idx),
}

sky = pysm.Sky(sky_config)

# %% [markdown]
# # PICO configuration

# %%
datapath=share_datapath +  '/bmode_moments_sims/pico/s2d2/'
ensure_dir(datapath)

pico_config={
    'nside' : nside,
    'frequencies' : pico.channels, #Expected in GHz
    'use_smoothing' : True,
    'beams' : pico.beams, #Expected in arcmin
    'add_noise' : True,
    'sens_I' : pico.noiserms, 
    'sens_P' : pico.noiserms,
    'noise_seed' : 1234,
    'cmb_seed' : 1236,
    'use_bandpass' : False,
    'output_units' : 'uK_CMB',
    'output_directory' : datapath,
    'output_prefix' : fname_prefix,
}

pico_instrument = pysm.Instrument(pico_config)

pico_instrument.observe(sky)
# Out:
# nu (GHz) | sigma_I (uK_CMB amin) | sigma_P (uK_CMB amin) | FWHM (arcmin)
#
# 0021.00 | 16.90 | 16.90 | 38.40
# 0025.00 | 13.00 | 13.00 | 32.00
# 0030.00 | 08.70 | 08.70 | 28.30
# 0036.00 | 05.60 | 05.60 | 23.60
# 0043.20 | 05.60 | 05.60 | 22.20
# 0051.80 | 04.00 | 04.00 | 18.40
# 0062.20 | 03.80 | 03.80 | 12.80
# 0074.60 | 03.00 | 03.00 | 10.70
# 0089.60 | 02.00 | 02.00 | 09.50
# 0107.50 | 01.60 | 01.60 | 07.90
# 0129.00 | 01.50 | 01.50 | 07.40
# 0154.80 | 01.30 | 01.30 | 06.20
# 0185.80 | 02.80 | 02.80 | 04.30
# 0222.90 | 03.20 | 03.20 | 03.60
# 0267.50 | 02.20 | 02.20 | 03.20
# 0321.00 | 03.00 | 03.00 | 02.60
# 0385.20 | 03.20 | 03.20 | 02.50
# 0462.20 | 06.40 | 06.40 | 02.10
# 0554.70 | 32.40 | 32.40 | 01.50
# 0665.60 | 125.00 | 125.00 | 01.30
# 0798.70 | 740.00 | 740.00 | 01.10
# Instrument attribute 'pixel_indices' not set.
# Instrument attribute 'pixel_indices' not set.
# Instrument attribute 'pixel_indices' not set.
# [2.46257024 2.45969486 2.46166142]
# ...

# %% [markdown]
# # LiteBird Configuration

# %%
datapath=share_datapath +  '/bmode_moments_sims/litebird/s2d2/'
ensure_dir(datapath)

litebird_config={
    'nside' : nside,
    'frequencies' : litebird.channels, #Expected in GHz
    'use_smoothing' : True,
    'beams' : litebird.beams, #Expected in arcmin
    'add_noise' : True,
    'sens_I' : litebird.noiserms, #Expected in units uK_RJ
    'sens_P' : litebird.noiserms,
    'noise_seed' : 1234,
    'cmb_seed' : 1236,
    'use_bandpass' : False,
    'output_units' : 'uK_CMB',
    'output_directory' : datapath,
    'output_prefix' : fname_prefix,
}

litebird_instrument = pysm.Instrument(litebird_config)

litebird_instrument.observe(sky)
# Out:
# nu (GHz) | sigma_I (uK_CMB amin) | sigma_P (uK_CMB amin) | FWHM (arcmin)
#
# 0040.00 | 37.50 | 37.50 | 69.30
# 0050.00 | 24.00 | 24.00 | 56.80
# 0060.00 | 19.90 | 19.90 | 49.00
# 0068.00 | 16.20 | 16.20 | 42.50
# 0078.00 | 13.50 | 13.50 | 37.80
# 0089.00 | 11.70 | 11.70 | 34.10
# 0100.00 | 09.20 | 09.20 | 35.70
# 0119.00 | 07.60 | 07.60 | 29.80
# 0140.00 | 05.90 | 05.90 | 28.90
# 0166.00 | 06.50 | 06.50 | 28.90
# 0195.00 | 05.80 | 05.80 | 28.20
# 0235.00 | 07.70 | 07.70 | 24.70
# 0280.00 | 13.20 | 13.20 | 22.50
# 0337.00 | 19.50 | 19.50 | 20.90
# 0402.00 | 37.50 | 37.50 | 17.90
# Instrument attribute 'pixel_indices' not set.
# Instrument attribute 'pixel_indices' not set.
# Instrument attribute 'pixel_indices' not set.
# [5.46428307 5.45790279 5.46226647]
# [103.29381573   7.90553975   4.02626613]
# Instrument attribute 'pixel_indices' not set.
# Instrument attribute 'pixel_indices' not set.
# [3.49307165 3.49351179 3.48995279]
# [104.90033007   4.71771297   2.28295558]
# ...

# %% [markdown]
# # Testing simulations

# %%
dlb=h.read_map("../dataout/bmode_moments_sims/litebird/s2d2/sim_nu0100p00GHz_total_nside0512.fits",(0,1,2))
dn=h.read_map("../dataout/bmode_moments_sims/litebird/s2d2/sim_nu0100p00GHz_noise_nside0512.fits",(0,1,2))
# Out:
# NSIDE = 512
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT
# NSIDE = 512
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %%
h.mollview(dlb[2],norm="hist")
h.mollview(dn[2],norm="hist")
# Out:
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="850">

# %%
alm=h.map2alm(dlb,lmax=1024,pol=True) ; cl=h.alm2cl(alm[2])
almn=h.map2alm(dn,lmax=1024,pol=True) ; cln=h.alm2cl(almn[2])
ell=arange(np.size(cl))

# %%
figure()
plot(ell,ell*(ell+1)*(cl-cln))
# plot(ell,ell*(ell+1)*cln)
# Out:
# <img src="data:image/png;base64,..." width="640">
